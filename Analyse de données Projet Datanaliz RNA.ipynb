# %% [markdown]
# # Projet - Analyse de données - Associations

# %% [markdown]
# Segmenter les régions

# %% [markdown]
# Analyser les dates de création des asssos en fonction des thématiques des régions

# %% [markdown]
# # Chargement des données

# %%
import pandas
import matplotlib.pyplot as plt

assos=pandas.read_csv("ref-france-association-repertoire-national.csv", sep=";")
assos
# Out:
#                      Id   Ancien Id SIRET Numéro de RUP Gestion  \
# 0        741P0741014598  0741014598   NaN           NaN    741P
# 1        741P0741014686  0741014686   NaN           NaN    741P
# 2        741P0741014759  0741014759   NaN           NaN    741P
# 3        741P0741014812  0741014812   NaN           NaN    741P
# 4        741P0741014823  0741014823   NaN           NaN    741P
# ...                 ...         ...   ...           ...     ...
# 3107601      W251003011         NaN   NaN           NaN    251P
# 3107602      W251003035         NaN   NaN           NaN    251P
# 3107603      W251003056         NaN   NaN           NaN    251P
# 3107604      W251003062  0251016744   NaN           NaN    251P
# 3107605      W251003082  0251015537   NaN           NaN    251P
#
#         Date de création Date de déclaration Date de publication  \
# 0             2005-12-02                 NaN                 NaN
# 1             2006-03-23                 NaN                 NaN
# 2             2006-07-24                 NaN                 NaN
# 3             2006-10-09                 NaN                 NaN
# 4             2006-10-19                 NaN                 NaN
# ...                  ...                 ...                 ...
# 3107601       2012-04-23          2020-12-23          2012-05-12
# 3107602       2012-05-22          2012-05-22          2012-06-02
# 3107603       2012-06-04          2018-12-27          2012-06-23
# 3107604       2005-09-21          2014-07-04          2005-10-15
# 3107605       2001-06-07          2020-05-28          2001-07-01
#
#         Date de dissolution Nature  ... SIte Web Publication sur le web  \
# 0                       NaN      D  ...      NaN     aucune information
# 1                       NaN      D  ...      NaN     aucune information
# 2                       NaN      D  ...      NaN     aucune information
# 3                       NaN      D  ...      NaN     aucune information
# 4                       NaN      D  ...      NaN     aucune information
# ...                     ...    ...  ...      ...                    ...
# 3107601                 NaN      D  ...      NaN                    non
# 3107602                 NaN      D  ...      NaN                    non
# 3107603                 NaN      D  ...      NaN                    non
# 3107604                 NaN      D  ...      NaN                    non
# 3107605                 NaN      D  ...      NaN                    non
#
#                              Observation Position        Date de Mise à jour  \
# 0        Reprise  =>  date ag=0000-00-00   Active  2008-11-26T12:38:49+01:00
# 1        Reprise  =>  date ag=0000-00-00   Active  2008-11-26T12:38:51+01:00
# 2        Reprise  =>  date ag=0000-00-00   Active  2008-11-26T12:38:52+01:00
# 3        Reprise  =>  date ag=0000-00-00   Active  2008-11-26T12:38:53+01:00
# 4                             W741009580        R  2020-03-05T04:13:59+01:00
# ...                                  ...      ...                        ...
# 3107601                              NaN   Active  2021-06-24T22:00:02+02:00
# 3107602                              NaN   Active  2012-06-02T14:46:05+02:00
# 3107603                              NaN   Active  2019-06-28T22:00:03+02:00
# 3107604                              NaN   Active  2015-01-02T21:00:07+01:00
# 3107605                              NaN   Active  2020-06-11T16:02:41+02:00
#
#                geo_point_2d Nom Officiel Département  \
# 0        45.887063,6.076321                      NaN
# 1         45.88142,6.323178             Haute-Savoie
# 2        45.993193,6.289847             Haute-Savoie
# 3        45.945411,6.058328             Haute-Savoie
# 4        45.887063,6.076321                      NaN
# ...                     ...                      ...
# 3107601  47.249188,6.055178                    Doubs
# 3107602  47.505804,6.463836                    Doubs
# 3107603   47.273283,6.00152                    Doubs
# 3107604   47.216777,6.05008                    Doubs
# 3107605  47.343432,6.309565                    Doubs
#
#                    Nom Officiel EPCI      Nom Officiel Région  \
# 0                                NaN                      NaN
# 1           CC des Vallées de Thônes     Auvergne-Rhône-Alpes
# 2                 CA du Grand Annecy     Auvergne-Rhône-Alpes
# 3                   CC Fier et Usses     Auvergne-Rhône-Alpes
# 4                                NaN                      NaN
# ...                              ...                      ...
# 3107601  CU Grand Besançon Métropole  Bourgogne-Franche-Comté
# 3107602   CC des Deux Vallées Vertes  Bourgogne-Franche-Comté
# 3107603  CU Grand Besançon Métropole  Bourgogne-Franche-Comté
# 3107604  CU Grand Besançon Métropole  Bourgogne-Franche-Comté
# 3107605          CC du Doubs Baumois  Bourgogne-Franche-Comté
#
#         Code Iso 3166-3 Zone
# 0                        NaN
# 1                        FXX
# 2                        FXX
# 3                        FXX
# 4                        NaN
# ...                      ...
# 3107601                  FXX
# 3107602                  FXX
# 3107603                  FXX
# 3107604                  FXX
# 3107605                  FXX
#
# [3107606 rows x 42 columns]

# %%
assos_study=pandas.read_csv("ref-france-association-repertoire-national.csv", sep=";",nrows=25000)
assos_study.head()
# Out:
#                Id   Ancien Id  SIRET Numéro de RUP Gestion Date de création  \
# 0  741P0741014598  0741014598    NaN           NaN    741P       2005-12-02
# 1  741P0741014686  0741014686    NaN           NaN    741P       2006-03-23
# 2  741P0741014759  0741014759    NaN           NaN    741P       2006-07-24
# 3  741P0741014812  0741014812    NaN           NaN    741P       2006-10-09
# 4  741P0741014823  0741014823    NaN           NaN    741P       2006-10-19
#
#   Date de déclaration Date de publication Date de dissolution Nature  ...  \
# 0                 NaN                 NaN                 NaN      D  ...
# 1                 NaN                 NaN                 NaN      D  ...
# 2                 NaN                 NaN                 NaN      D  ...
# 3                 NaN                 NaN                 NaN      D  ...
# 4                 NaN                 NaN                 NaN      D  ...
#
#   SIte Web Publication sur le web                      Observation Position  \
# 0      NaN     aucune information  Reprise  =>  date ag=0000-00-00   Active
# 1      NaN     aucune information  Reprise  =>  date ag=0000-00-00   Active
# 2      NaN     aucune information  Reprise  =>  date ag=0000-00-00   Active
# 3      NaN     aucune information  Reprise  =>  date ag=0000-00-00   Active
# 4      NaN     aucune information                       W741009580        R
#
#          Date de Mise à jour        geo_point_2d Nom Officiel Département  \
# 0  2008-11-26T12:38:49+01:00  45.887063,6.076321                      NaN
# 1  2008-11-26T12:38:51+01:00   45.88142,6.323178             Haute-Savoie
# 2  2008-11-26T12:38:52+01:00  45.993193,6.289847             Haute-Savoie
# 3  2008-11-26T12:38:53+01:00  45.945411,6.058328             Haute-Savoie
# 4  2020-03-05T04:13:59+01:00  45.887063,6.076321                      NaN
#
#           Nom Officiel EPCI   Nom Officiel Région Code Iso 3166-3 Zone
# 0                       NaN                   NaN                  NaN
# 1  CC des Vallées de Thônes  Auvergne-Rhône-Alpes                  FXX
# 2        CA du Grand Annecy  Auvergne-Rhône-Alpes                  FXX
# 3          CC Fier et Usses  Auvergne-Rhône-Alpes                  FXX
# 4                       NaN                   NaN                  NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# # Nettoyage des données

# %% [markdown]
# ## Analyse des différents champs
# On va essayer d'analyser les différents champs que nous avons à disposition pour concentrer nos analyses que sur les axes les plus pertinents. Deux types de colonnes qui vont pouvoir être retirées:
# * les colonnes qui ne sont pas directement utiles pour notre but premier
# * les colonnes qui sont complètement, ou presque complètement, vides, et qui ne pourront pas contribuer beaucoup à l'analyse.

# %%
assos_study.info(show_counts=True,verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 42 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Id                                          25000 non-null  object
#  1   Ancien Id                                   22636 non-null  object
#  2   SIRET                                       167 non-null    float64
#  3   Numéro de RUP                               1 non-null      object
#  4   Gestion                                     25000 non-null  object
#  5   Date de création                            15031 non-null  object
#  6   Date de déclaration                         4677 non-null   object
#  7   Date de publication                         15322 non-null  object
#  8   Date de dissolution                         544 non-null    object
#  9   Nature                                      25000 non-null  object
#  10  Groupement                                  25000 non-null  object
#  11  Titre                                       24953 non-null  object
#  12  Titre court                                 4672 non-null   object
#  13  Objet                                       24656 non-null  object
#  14  Objet Social 1                              24685 non-null  float64
#  15  Objet Social 2                              25000 non-null  int64
#  16  Complément d'adresse Siège                  14632 non-null  object
#  17  Numéro de Voie Siège                        0 non-null      float64
#  18  Type de Voie Siège                          0 non-null      float64
#  19  Libellé Voie Siège                          10115 non-null  object
#  20  Lieu Dit Siège                              711 non-null    object
#  21  Code Officiel Commune Siège                 25000 non-null  object
#  22  Code Postal Siège                           24998 non-null  object
#  23  Nom Commune Siège                           24508 non-null  object
#  24  Complément Adresse Gestion                  0 non-null      float64
#  25  Complément Géo Adresse Gestion              0 non-null      float64
#  26  Libellé Voie Adresse Gestion                0 non-null      float64
#  27  Lieu Dit Adresse Gestion                    0 non-null      float64
#  28  Code Postal Adresse Gestion                 0 non-null      float64
#  29  Autre Adresse Gestion                       0 non-null      float64
#  30  Pays Adresse Gestion                        0 non-null      float64
#  31  Code de la civilité du dirigeant principal  24999 non-null  object
#  32  SIte Web                                    188 non-null    object
#  33  Publication sur le web                      25000 non-null  object
#  34  Observation                                 13525 non-null  object
#  35  Position                                    25000 non-null  object
#  36  Date de Mise à jour                         25000 non-null  object
#  37  geo_point_2d                                23388 non-null  object
#  38  Nom Officiel Département                    22405 non-null  object
#  39  Nom Officiel EPCI                           22370 non-null  object
#  40  Nom Officiel Région                         23230 non-null  object
#  41  Code Iso 3166-3 Zone                        23230 non-null  object
# dtypes: float64(11), int64(1), object(30)
# memory usage: 8.0+ MB

# %%
#On va déterminer le nombre de valeurs renseignées par colonnes 
CountedValues=assos_study.count()
CountedValues.plot.hist()
plt.show()

# %% [markdown]
# ### Suppression des colonnes vides
# Filtrons pour pouvoir supprimer toutes les colonnes vides

# %%
CountedValues=assos_study.count()

Colonnes_Gardees=CountedValues>0
Colonnes_Gardees

Indexs=CountedValues[Colonnes_Gardees].index

assos_study[Indexs]
# Out:
#                    Id   Ancien Id  SIRET Numéro de RUP Gestion  \
# 0      741P0741014598  0741014598    NaN           NaN    741P
# 1      741P0741014686  0741014686    NaN           NaN    741P
# 2      741P0741014759  0741014759    NaN           NaN    741P
# 3      741P0741014812  0741014812    NaN           NaN    741P
# 4      741P0741014823  0741014823    NaN           NaN    741P
# ...               ...         ...    ...           ...     ...
# 24995      W451003530  0451001255    NaN           NaN    451S
# 24996      W451003567  0451006083    NaN           NaN    451S
# 24997      W451003623  0451007294    NaN           NaN    451S
# 24998      W451003672         NaN    NaN           NaN    451S
# 24999      W451003702  0451001434    NaN           NaN    451S
#
#       Date de création Date de déclaration Date de publication  \
# 0           2005-12-02                 NaN                 NaN
# 1           2006-03-23                 NaN                 NaN
# 2           2006-07-24                 NaN                 NaN
# 3           2006-10-09                 NaN                 NaN
# 4           2006-10-19                 NaN                 NaN
# ...                ...                 ...                 ...
# 24995       1979-09-20          1979-09-13          1979-09-20
# 24996       1996-03-27          1996-04-05                 NaN
# 24997       2007-10-10          2007-10-10                 NaN
# 24998       2015-07-06          2015-07-06          2015-08-01
# 24999       1981-11-30          1981-11-30          1981-12-06
#
#       Date de dissolution Nature  ... SIte Web Publication sur le web  \
# 0                     NaN      D  ...      NaN     aucune information
# 1                     NaN      D  ...      NaN     aucune information
# 2                     NaN      D  ...      NaN     aucune information
# 3                     NaN      D  ...      NaN     aucune information
# 4                     NaN      D  ...      NaN     aucune information
# ...                   ...    ...  ...      ...                    ...
# 24995                 NaN      D  ...      NaN                    non
# 24996                 NaN      D  ...      NaN                    non
# 24997                 NaN      D  ...      NaN                    non
# 24998                 NaN      D  ...      NaN                    non
# 24999                 NaN      D  ...      NaN                    non
#
#                                              Observation Position  \
# 0                        Reprise  =>  date ag=0000-00-00   Active
# 1                        Reprise  =>  date ag=0000-00-00   Active
# 2                        Reprise  =>  date ag=0000-00-00   Active
# 3                        Reprise  =>  date ag=0000-00-00   Active
# 4                                             W741009580        R
# ...                                                  ...      ...
# 24995  Reprise auto =>  date publication création au ...   Active
# 24996  Reprise auto =>  date publication création au ...   Active
# 24997                                                NaN   Active
# 24998                                                NaN   Active
# 24999  Reprise auto =>  date publication création au ...   Active
#
#              Date de Mise à jour        geo_point_2d Nom Officiel Département  \
# 0      2008-11-26T12:38:49+01:00  45.887063,6.076321                      NaN
# 1      2008-11-26T12:38:51+01:00   45.88142,6.323178             Haute-Savoie
# 2      2008-11-26T12:38:52+01:00  45.993193,6.289847             Haute-Savoie
# 3      2008-11-26T12:38:53+01:00  45.945411,6.058328             Haute-Savoie
# 4      2020-03-05T04:13:59+01:00  45.887063,6.076321                      NaN
# ...                          ...                 ...                      ...
# 24995  2017-03-27T12:16:41+02:00  47.854613,2.735016                   Loiret
# 24996  2017-03-27T11:59:06+02:00  47.939832,2.738113                   Loiret
# 24997  2015-06-24T16:25:42+02:00  48.004407,2.707835                   Loiret
# 24998  2015-08-01T14:45:23+02:00  48.111296,2.560877                   Loiret
# 24999  2017-03-27T10:59:45+02:00  48.035837,2.935802                   Loiret
#
#                                Nom Officiel EPCI   Nom Officiel Région  \
# 0                                            NaN                   NaN
# 1                       CC des Vallées de Thônes  Auvergne-Rhône-Alpes
# 2                             CA du Grand Annecy  Auvergne-Rhône-Alpes
# 3                               CC Fier et Usses  Auvergne-Rhône-Alpes
# 4                                            NaN                   NaN
# ...                                          ...                   ...
# 24995            CC Canaux et Forêts en Gâtinais   Centre-Val de Loire
# 24996  CA Montargoise et Rives du Loing (A.M.E.)   Centre-Val de Loire
# 24997  CA Montargoise et Rives du Loing (A.M.E.)   Centre-Val de Loire
# 24998                      CC des Quatre Vallées   Centre-Val de Loire
# 24999      CC de la Cléry,du Betz et de l'Ouanne   Centre-Val de Loire
#
#       Code Iso 3166-3 Zone
# 0                      NaN
# 1                      FXX
# 2                      FXX
# 3                      FXX
# 4                      NaN
# ...                    ...
# 24995                  FXX
# 24996                  FXX
# 24997                  FXX
# 24998                  FXX
# 24999                  FXX
#
# [25000 rows x 33 columns]

# %% [markdown]
# ### Filtrage des colonnes (nombre de valeurs supérieurs 15000)
# Le filtrage pour des colonnes avec des valeurs supérieures à 15000 nous permet de se passer de la colonne ancien id.

# %%
CountedValues=assos_study.count()
CountedValues

Colonnes_Gardees15000=CountedValues>15000
Colonnes_Gardees15000

Indexs15000=CountedValues[Colonnes_Gardees15000].index
Indexs15000
assos_study_filtre=assos_study[Indexs15000]
assos_study_filtre
del assos_study_filtre["Ancien Id"]
del assos_study_filtre["Date de publication"]
assos_study_filtre
# Out:
#                    Id Gestion Date de création Nature Groupement  \
# 0      741P0741014598    741P       2005-12-02      D     Simple
# 1      741P0741014686    741P       2006-03-23      D     Simple
# 2      741P0741014759    741P       2006-07-24      D     Simple
# 3      741P0741014812    741P       2006-10-09      D     Simple
# 4      741P0741014823    741P       2006-10-19      D     Simple
# ...               ...     ...              ...    ...        ...
# 24995      W451003530    451S       1979-09-20      D     Simple
# 24996      W451003567    451S       1996-03-27      D     Simple
# 24997      W451003623    451S       2007-10-10      D     Simple
# 24998      W451003672    451S       2015-07-06      D     Simple
# 24999      W451003702    451S       1981-11-30      D     Simple
#
#                                            Titre  \
# 0                                     CREANOSTRA
# 1                             CLASSE 2007 THÔNES
# 2                         NON NOBIS HAUTE-SAVOIE
# 3                                    TEAM YAKUZA
# 4                                DE FIL EN PATCH
# ...                                          ...
# 24995              LA COMPAGNIE DE LA MUSARAIGNE
# 24996  COMITE DES FETES DE MORMANT SUR VERNISSON
# 24997                LBL (LIGUE BREACKER LOIRET)
# 24998                      L'AMICALE DES BASSINS
# 24999           AMICALE PETANQUE CLUB COURTEMAUX
#
#                                                    Objet  Objet Social 1  \
# 0      De promouvoir la formation et ses membres par ...         15000.0
# 1            Réunir les personnes de Thônes nées en 1987          7000.0
# 2      L'accompagnement, le soutien et le développeme...         24000.0
# 3      Rassembler des passionnés de personnalisation ...         11000.0
# 4      De rassembler des personnes activement intéres...          7000.0
# ...                                                  ...             ...
# 24995                                                  o          6070.0
# 24996                                                  o          9030.0
# 24997   pratique de la danse 'hip hop' et 'breack dance'          6040.0
# 24998  destruction des nuisibles fouisseurs pour la p...         10022.0
# 24999            favoriser la pratique du sport pétanque         11035.0
#
#        Objet Social 2 Code Officiel Commune Siège  ...      Nom Commune Siège  \
# 0               15075                       74268  ...                 Seynod
# 1                7075                       74280  ...                 Thones
# 2               20005                       74282  ...        Thorens-glieres
# 3               11160                       74272  ...               Sillingy
# 4                6090                       74268  ...                 Seynod
# ...               ...                         ...  ...                    ...
# 24995               0                       45229  ...   Nogent-sur-Vernisson
# 24996               0                       45216  ...  Mormant-sur-Vernisson
# 24997               0                       45247  ...                 Pannes
# 24998               0                       45303  ...     Sceaux-du-Gâtinais
# 24999               0                       45113  ...             Courtemaux
#
#       Code de la civilité du dirigeant principal Publication sur le web  \
# 0                                             PM     aucune information
# 1                                             PM     aucune information
# 2                                             PM     aucune information
# 3                                             PM     aucune information
# 4                                             PM     aucune information
# ...                                          ...                    ...
# 24995                                         PM                    non
# 24996                                         PM                    non
# 24997                                         PM                    non
# 24998                                         PM                    non
# 24999                                         PM                    non
#
#       Position        Date de Mise à jour        geo_point_2d  \
# 0       Active  2008-11-26T12:38:49+01:00  45.887063,6.076321
# 1       Active  2008-11-26T12:38:51+01:00   45.88142,6.323178
# 2       Active  2008-11-26T12:38:52+01:00  45.993193,6.289847
# 3       Active  2008-11-26T12:38:53+01:00  45.945411,6.058328
# 4            R  2020-03-05T04:13:59+01:00  45.887063,6.076321
# ...        ...                        ...                 ...
# 24995   Active  2017-03-27T12:16:41+02:00  47.854613,2.735016
# 24996   Active  2017-03-27T11:59:06+02:00  47.939832,2.738113
# 24997   Active  2015-06-24T16:25:42+02:00  48.004407,2.707835
# 24998   Active  2015-08-01T14:45:23+02:00  48.111296,2.560877
# 24999   Active  2017-03-27T10:59:45+02:00  48.035837,2.935802
#
#       Nom Officiel Département                          Nom Officiel EPCI  \
# 0                          NaN                                        NaN
# 1                 Haute-Savoie                   CC des Vallées de Thônes
# 2                 Haute-Savoie                         CA du Grand Annecy
# 3                 Haute-Savoie                           CC Fier et Usses
# 4                          NaN                                        NaN
# ...                        ...                                        ...
# 24995                   Loiret            CC Canaux et Forêts en Gâtinais
# 24996                   Loiret  CA Montargoise et Rives du Loing (A.M.E.)
# 24997                   Loiret  CA Montargoise et Rives du Loing (A.M.E.)
# 24998                   Loiret                      CC des Quatre Vallées
# 24999                   Loiret      CC de la Cléry,du Betz et de l'Ouanne
#
#         Nom Officiel Région Code Iso 3166-3 Zone
# 0                       NaN                  NaN
# 1      Auvergne-Rhône-Alpes                  FXX
# 2      Auvergne-Rhône-Alpes                  FXX
# 3      Auvergne-Rhône-Alpes                  FXX
# 4                       NaN                  NaN
# ...                     ...                  ...
# 24995   Centre-Val de Loire                  FXX
# 24996   Centre-Val de Loire                  FXX
# 24997   Centre-Val de Loire                  FXX
# 24998   Centre-Val de Loire                  FXX
# 24999   Centre-Val de Loire                  FXX
#
# [25000 rows x 21 columns]

# %%
assos_study_filtre.columns
# Out:
# Index(['Id', 'Gestion', 'Date de création', 'Nature', 'Groupement', 'Titre',
#        'Objet', 'Objet Social 1', 'Objet Social 2',
#        'Code Officiel Commune Siège', 'Code Postal Siège', 'Nom Commune Siège',
#        'Code de la civilité du dirigeant principal', 'Publication sur le web',
#        'Position', 'Date de Mise à jour', 'geo_point_2d',
#        'Nom Officiel Département', 'Nom Officiel EPCI', 'Nom Officiel Région',
#        'Code Iso 3166-3 Zone'],
#       dtype='object')

# %% [markdown]
# On va essayer de faire un chargement des données qu'avec les colonnes sélectionnées

# %%
assos_study_filtre=pandas.read_csv("ref-france-association-repertoire-national.csv", sep=";", usecols=Indexs15000)

# %%
assos_study_filtre.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3107606 entries, 0 to 3107605
# Data columns (total 23 columns):
#  #   Column                                      Dtype
# ---  ------                                      -----
#  0   Id                                          object
#  1   Ancien Id                                   object
#  2   Gestion                                     object
#  3   Date de création                            object
#  4   Date de publication                         object
#  5   Nature                                      object
#  6   Groupement                                  object
#  7   Titre                                       object
#  8   Objet                                       object
#  9   Objet Social 1                              float64
#  10  Objet Social 2                              object
#  11  Code Officiel Commune Siège                 object
#  12  Code Postal Siège                           object
#  13  Nom Commune Siège                           object
#  14  Code de la civilité du dirigeant principal  object
#  15  Publication sur le web                      object
#  16  Position                                    object
#  17  Date de Mise à jour                         object
#  18  geo_point_2d                                object
#  19  Nom Officiel Département                    object
#  20  Nom Officiel EPCI                           object
#  21  Nom Officiel Région                         object
#  22  Code Iso 3166-3 Zone                        object
# dtypes: float64(1), object(22)
# memory usage: 4.7 GB

# %% [markdown]
# ## Modélisons explicitement les variables catégorielles

# %%
Valeurs_uniques_by_column=assos_study_filtre.nunique()
Valeurs_uniques_by_column
# Out:
# Id                                            3107606
# Ancien Id                                     1794534
# Gestion                                           337
# Date de création                                40208
# Date de publication                             35277
# Nature                                             16
# Groupement                                          3
# Titre                                         2696080
# Objet                                         2633543
# Objet Social 1                                    581
# Objet Social 2                                    802
# Code Officiel Commune Siège                     65766
# Code Postal Siège                               18328
# Nom Commune Siège                               62134
# Code de la civilité du dirigeant principal         52
# Publication sur le web                              3
# Position                                            5
# Date de Mise à jour                           1118003
# geo_point_2d                                    38551
# Nom Officiel Département                          105
# Nom Officiel EPCI                                1204
# Nom Officiel Région                                24
# Code Iso 3166-3 Zone                               12
# dtype: int64

# %%
assos_study_filtre.Position.unique()
# Out:
# array(['Active', 'R', 'Dissoute', 'Supprimée', nan, 'I'], dtype=object)

# %%
from pandas.api.types import CategoricalDtype
dtype ={
    "Nature":"category",
    "Groupement":"category",
    "Position":"category",
    "Publication sur le web":"category",
}

# %%
assos_study_filtre_categ=pandas.read_csv("ref-france-association-repertoire-national.csv", sep=";", usecols=Indexs15000,dtype ={
    "Nature":"category",
    "Groupement":"category",
    "Position":"category",
    "Publication sur le web":"category",
})

# %%
assos_study_filtre_categ.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3107606 entries, 0 to 3107605
# Data columns (total 23 columns):
#  #   Column                                      Dtype
# ---  ------                                      -----
#  0   Id                                          object
#  1   Ancien Id                                   object
#  2   Gestion                                     object
#  3   Date de création                            object
#  4   Date de publication                         object
#  5   Nature                                      category
#  6   Groupement                                  category
#  7   Titre                                       object
#  8   Objet                                       object
#  9   Objet Social 1                              float64
#  10  Objet Social 2                              object
#  11  Code Officiel Commune Siège                 object
#  12  Code Postal Siège                           object
#  13  Nom Commune Siège                           object
#  14  Code de la civilité du dirigeant principal  object
#  15  Publication sur le web                      category
#  16  Position                                    category
#  17  Date de Mise à jour                         object
#  18  geo_point_2d                                object
#  19  Nom Officiel Département                    object
#  20  Nom Officiel EPCI                           object
#  21  Nom Officiel Région                         object
#  22  Code Iso 3166-3 Zone                        object
# dtypes: category(4), float64(1), object(18)
# memory usage: 4.0 GB
